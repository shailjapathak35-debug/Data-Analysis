# %% [markdown]
# #DSV Assignment-2

# %% [markdown]
# 1.   **Name**-Shailja Pathak
#
# 1.   **Uni Roll No.**-12515001471
#
# 1.   **Class Roll No.**-49
#
# 2.   **Section**-AC
#
# 1.   **Subject**-Data Science & Visualization

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/crime_dataset_india.csv', sep='\t')

# %%
df.head()
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0              1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1              2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2              3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3              4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4              5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
#
#         City  Crime Code Crime Description  Victim Age Victim Gender  \
# 0  Ahmedabad         576    IDENTITY THEFT          16             M
# 1    Chennai         128          HOMICIDE          37             M
# ...

# %%
df.head(10)
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0              1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1              2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2              3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3              4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4              5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# 5              6  02-01-2020 03:00   01-01-2020 05:00   01-01-2020 17:09
# 6              7  01-01-2020 16:00   01-01-2020 06:00   01-01-2020 14:08
# 7              8  02-01-2020 10:00   01-01-2020 07:00   02-01-2020 06:33
# ...

# %%
#for the last rows
df.tail()
#naturally print the last 5 rows
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00   07-31-2024 06:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
#           City  Crime Code   Crime Description  Victim Age Victim Gender  \
# 40155  Kolkata         312      COUNTERFEITING          78             F
# 40156   Mumbai         300  ILLEGAL POSSESSION          75             F
# 40157   Kanpur         423    VEHICLE - STOLEN          68             M
# 40158    Patna         311      SEXUAL ASSAULT          11             M
# 40159    Delhi         193   DOMESTIC VIOLENCE          43             F
#
# ...

# %%
#will print the random 5 rows from the whole dataset
df.sample(5)
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 33411          33412  24-10-2023 11:00   10-24-2023 03:00   25-10-2023 00:29
# 790              791  03-02-2020 19:00   02-02-2020 22:00   03-02-2020 02:46
# 32049          32050  28-08-2023 12:00   08-28-2023 09:00   28-08-2023 10:19
# 22280          22281  19-07-2022 06:00   07-17-2022 08:00   18-07-2022 03:19
# 19259          19260  14-03-2022 15:00   03-13-2022 11:00   13-03-2022 16:42
#
#             City  Crime Code Crime Description  Victim Age Victim Gender  \
# 33411      Delhi         527             ARSON          46             F
# 790       Indore         480  VEHICLE - STOLEN          41             F
# 32049  Ghaziabad         533       SHOPLIFTING          66             M
# 22280    Chennai         470        CYBERCRIME          25             F
# 19259  Bangalore         250             ARSON          39             M
#
# ...

# %%
#basic information about the dataset
#basically the rows and the columns
df.shape
# Out:
# (40160, 14)

# %%
#specifically for the number of rows
df.shape[0]
# Out:
# 40160

# %%
#specifically for the number of columns
df.shape[1]
# Out:
# 14

# %%
#will print the column names
df.columns
# Out:
# Index(['Report Number', 'Date Reported', 'Date of Occurrence',
#        'Time of Occurrence', 'City', 'Crime Code', 'Crime Description',
#        'Victim Age', 'Victim Gender', 'Weapon Used', 'Crime Domain',
#        'Police Deployed', 'Case Closed', 'Date Case Closed'],
#       dtype='object')

# %%
#column name in list format
df.columns.tolist()
# Out:
# ['Report Number',
#  'Date Reported',
#  'Date of Occurrence',
#  'Time of Occurrence',
#  'City',
#  'Crime Code',
#  'Crime Description',
#  'Victim Age',
#  'Victim Gender',
#  'Weapon Used',
#  'Crime Domain',
#  'Police Deployed',
#  'Case Closed',
#  'Date Case Closed']

# %%
#print the information about the datatypes
df.dtypes
# Out:
# Report Number          int64
# Date Reported         object
# Date of Occurrence    object
# Time of Occurrence    object
# City                  object
# Crime Code             int64
# Crime Description     object
# Victim Age             int64
# Victim Gender         object
# Weapon Used           object
# Crime Domain          object
# Police Deployed        int64
# Case Closed           object
# Date Case Closed      object
# dtype: object

# %%
#for the complete information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Report Number       40160 non-null  int64
#  1   Date Reported       40160 non-null  object
#  2   Date of Occurrence  40160 non-null  object
#  3   Time of Occurrence  40160 non-null  object
#  4   City                40160 non-null  object
#  5   Crime Code          40160 non-null  int64
#  6   Crime Description   40160 non-null  object
#  7   Victim Age          40160 non-null  int64
#  8   Victim Gender       40160 non-null  object
#  9   Weapon Used         34370 non-null  object
#  10  Crime Domain        40160 non-null  object
#  11  Police Deployed     40160 non-null  int64
#  12  Case Closed         40160 non-null  object
#  13  Date Case Closed    20062 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 4.3+ MB

# %%
#gives statistical summary / info about the numeric column
df.describe()
# Out:
#        Report Number    Crime Code   Victim Age  Police Deployed
# count   40160.000000  40160.000000  40160.00000     40160.000000
# mean    20080.500000    349.360259     44.49126        10.006250
# std     11593.337742    144.169205     20.22555         5.467951
# min         1.000000    100.000000     10.00000         1.000000
# 25%     10040.750000    225.000000     27.00000         5.000000
# 50%     20080.500000    349.000000     44.00000        10.000000
# 75%     30120.250000    474.000000     62.00000        15.000000
# max     40160.000000    599.000000     79.00000        19.000000

# %%
#if we put this code then it will give then it will describe the object info
df.describe(include='object')
# Out:
#            Date Reported Date of Occurrence Time of Occurrence   City  \
# count              40160              40160              40160  40160
# unique             25546              40160              39886     29
# top     03-01-2022 20:00   07-30-2024 15:00   14-10-2022 06:54  Delhi
# freq                   7                  1                  3   5400
#
#        Crime Description Victim Gender Weapon Used Crime Domain Case Closed  \
# count              40160         40160       34370        40160       40160
# unique                21             3           6            4           2
# top             BURGLARY             F       Knife  Other Crime          No
# freq                1980         22423        5835        22948       20098
#
#         Date Case Closed
# count              20062
# unique             16011
# top     04-05-2024 18:00
# freq                   6

# %%
#this will give the whole summary
#numeric+categorial data
df.describe(include='all')
# Out:
#         Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# count    40160.000000             40160              40160              40160
# unique            NaN             25546              40160              39886
# top               NaN  03-01-2022 20:00   07-30-2024 15:00   14-10-2022 06:54
# freq              NaN                 7                  1                  3
# mean     20080.500000               NaN                NaN                NaN
# std      11593.337742               NaN                NaN                NaN
# min          1.000000               NaN                NaN                NaN
# 25%      10040.750000               NaN                NaN                NaN
# 50%      20080.500000               NaN                NaN                NaN
# 75%      30120.250000               NaN                NaN                NaN
# max      40160.000000               NaN                NaN                NaN
#
# ...

# %%
#check the missing value
df.isnull().count()
# Out:
# Report Number         40160
# Date Reported         40160
# Date of Occurrence    40160
# Time of Occurrence    40160
# City                  40160
# Crime Code            40160
# Crime Description     40160
# Victim Age            40160
# Victim Gender         40160
# Weapon Used           40160
# Crime Domain          40160
# Police Deployed       40160
# Case Closed           40160
# Date Case Closed      40160
# dtype: int64

# %%
#counting the missing value of each column
df.isnull().sum()
# Out:
# Report Number             0
# Date Reported             0
# Date of Occurrence        0
# Time of Occurrence        0
# City                      0
# Crime Code                0
# Crime Description         0
# Victim Age                0
# Victim Gender             0
# Weapon Used            5790
# Crime Domain              0
# Police Deployed           0
# Case Closed               0
# Date Case Closed      20098
# dtype: int64

# %%
#it will find the missing value %age
(df.isnull().sum() / len(df)) * 100
# Out:
# Report Number          0.000000
# Date Reported          0.000000
# Date of Occurrence     0.000000
# Time of Occurrence     0.000000
# City                   0.000000
# Crime Code             0.000000
# Crime Description      0.000000
# Victim Age             0.000000
# Victim Gender          0.000000
# Weapon Used           14.417331
# Crime Domain           0.000000
# Police Deployed        0.000000
# Case Closed            0.000000
# Date Case Closed      50.044821
# dtype: float64

# %%
#print only those columns which contain missing value
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Weapon Used          5790
# Date Case Closed    20098
# dtype: int64

# %%
#total missing values
df.isnull().sum().sum()
# Out:
# np.int64(25888)

# %%
#Check the duplicate values
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40155    False
# 40156    False
# 40157    False
# 40158    False
# 40159    False
# Length: 40160, dtype: bool

# %%
#Check the duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#To count unique values per column
df.nunique()
# Out:
# Report Number         40160
# Date Reported         25546
# Date of Occurrence    40160
# Time of Occurrence    39886
# City                     29
# Crime Code              500
# Crime Description        21
# Victim Age               70
# Victim Gender             3
# Weapon Used               6
# Crime Domain              4
# Police Deployed          19
# Case Closed               2
# Date Case Closed      16011
# dtype: int64

# %% [markdown]
# **Unique Values**

# %%
#how many unique values are there in the city
df['City'].nunique()
# Out:
# 29

# %%
#cities with unique values
df['City'].unique()
# Out:
# array(['Ahmedabad', 'Chennai', 'Ludhiana', 'Pune', 'Delhi', 'Mumbai',
#        'Surat', 'Visakhapatnam', 'Bangalore', 'Kolkata', 'Ghaziabad',
#        'Hyderabad', 'Jaipur', 'Lucknow', 'Bhopal', 'Patna', 'Kanpur',
#        'Varanasi', 'Nagpur', 'Meerut', 'Thane', 'Indore', 'Rajkot',
#        'Vasai', 'Agra', 'Kalyan', 'Nashik', 'Srinagar', 'Faridabad'],
#       dtype=object)

# %% [markdown]
# **Crime Description**

# %%
df['Crime Description'].unique().tolist()
# Out:
# ['IDENTITY THEFT',
#  'HOMICIDE',
#  'KIDNAPPING',
#  'BURGLARY',
#  'VANDALISM',
#  'ASSAULT',
#  'VEHICLE - STOLEN',
#  'COUNTERFEITING',
#  'EXTORTION',
#  'PUBLIC INTOXICATION',
#  'FRAUD',
#  'SEXUAL ASSAULT',
#  'DRUG OFFENSE',
#  'ARSON',
#  'CYBERCRIME',
#  'TRAFFIC VIOLATION',
#  'SHOPLIFTING',
#  'ILLEGAL POSSESSION',
#  'FIREARM OFFENSE',
#  'ROBBERY',
#  'DOMESTIC VIOLENCE']

# %%
#crime domains
df['Crime Domain'].unique()
# Out:
# array(['Violent Crime', 'Other Crime', 'Fire Accident',
#        'Traffic Fatality'], dtype=object)

# %%
#gender values
df['Victim Gender'].unique()
# Out:
# array(['M', 'F', 'X'], dtype=object)

# %% [markdown]
# **Values Count**

# %%
#weapons
df['Weapon Used'].unique()
# Out:
# array(['Blunt Object', 'Poison', 'Firearm', 'Other', 'Knife',
#        'Explosives', nan], dtype=object)

# %%
#top 10 crimes
df['Crime Description'].value_counts().head(10)
# Out:
# Crime Description
# BURGLARY             1980
# VANDALISM            1975
# FRAUD                1965
# DOMESTIC VIOLENCE    1932
# FIREARM OFFENSE      1931
# ROBBERY              1928
# KIDNAPPING           1920
# IDENTITY THEFT       1918
# SEXUAL ASSAULT       1917
# ASSAULT              1915
# Name: count, dtype: int64

# %%
#crime percentage
df['Crime Description'].value_counts(normalize=True) * 100
# Out:
# Crime Description
# BURGLARY               4.930279
# VANDALISM              4.917829
# FRAUD                  4.892928
# DOMESTIC VIOLENCE      4.810757
# FIREARM OFFENSE        4.808267
# ROBBERY                4.800797
# KIDNAPPING             4.780876
# IDENTITY THEFT         4.775896
# SEXUAL ASSAULT         4.773406
# ASSAULT                4.768426
# TRAFFIC VIOLATION      4.768426
# PUBLIC INTOXICATION    4.760956
# HOMICIDE               4.753486
# CYBERCRIME             4.728586
# ILLEGAL POSSESSION     4.718625
# ARSON                  4.716135
# DRUG OFFENSE           4.706175
# EXTORTION              4.663845
# COUNTERFEITING         4.658865
# VEHICLE - STOLEN       4.636454
# SHOPLIFTING            4.628984
# Name: proportion, dtype: float64

# %%
#crime percentage
df['Crime Description'].value_counts(normalize=True) * 100
# Out:
# Crime Description
# BURGLARY               4.930279
# VANDALISM              4.917829
# FRAUD                  4.892928
# DOMESTIC VIOLENCE      4.810757
# FIREARM OFFENSE        4.808267
# ROBBERY                4.800797
# KIDNAPPING             4.780876
# IDENTITY THEFT         4.775896
# SEXUAL ASSAULT         4.773406
# ASSAULT                4.768426
# TRAFFIC VIOLATION      4.768426
# PUBLIC INTOXICATION    4.760956
# HOMICIDE               4.753486
# CYBERCRIME             4.728586
# ILLEGAL POSSESSION     4.718625
# ARSON                  4.716135
# DRUG OFFENSE           4.706175
# EXTORTION              4.663845
# COUNTERFEITING         4.658865
# VEHICLE - STOLEN       4.636454
# SHOPLIFTING            4.628984
# Name: proportion, dtype: float64

# %%
#cities with most crime
df['City'].value_counts()
# Out:
# City
# Delhi            5400
# Mumbai           4415
# Bangalore        3588
# Hyderabad        2881
# Kolkata          2518
# Chennai          2493
# Pune             2212
# Ahmedabad        1817
# Jaipur           1479
# Lucknow          1456
# Kanpur           1112
# Surat            1111
# Nagpur           1053
# Agra              764
# Ludhiana          761
# Visakhapatnam     728
# Thane             706
# Ghaziabad         704
# Indore            699
# Patna             695
# Bhopal            690
# Meerut            395
# Srinagar          371
# Nashik            366
# Vasai             362
# Varanasi          355
# Kalyan            355
# Faridabad         354
# Rajkot            320
# Name: count, dtype: int64

# %%
df['Victim Age']
# Out:
# 0        16
# 1        37
# 2        48
# 3        49
# 4        30
#          ..
# 40155    78
# 40156    75
# 40157    68
# 40158    11
# 40159    43
# Name: Victim Age, Length: 40160, dtype: int64

# %%
df['Crime Description']
# Out:
# 0            IDENTITY THEFT
# 1                  HOMICIDE
# 2                KIDNAPPING
# 3                  BURGLARY
# 4                 VANDALISM
#                 ...
# 40155        COUNTERFEITING
# 40156    ILLEGAL POSSESSION
# 40157      VEHICLE - STOLEN
# 40158        SEXUAL ASSAULT
# 40159     DOMESTIC VIOLENCE
# Name: Crime Description, Length: 40160, dtype: object

# %%
df[df['Victim Age']>18]
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# 6                  7  01-01-2020 16:00   01-01-2020 06:00   01-01-2020 14:08
# ...              ...               ...                ...                ...
# 40154          40155  01-08-2024 11:00   07-31-2024 02:00   31-07-2024 12:59
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
df[df['Victim Age']>30].count()
# Out:
# Report Number         28078
# Date Reported         28078
# Date of Occurrence    28078
# Time of Occurrence    28078
# City                  28078
# Crime Code            28078
# Crime Description     28078
# Victim Age            28078
# Victim Gender         28078
# Weapon Used           23978
# Crime Domain          28078
# Police Deployed       28078
# Case Closed           28078
# Date Case Closed      14021
# dtype: int64

# %%
#Victim age <18
df[df['Victim Age'] <18]
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 5                  6  02-01-2020 03:00   01-01-2020 05:00   01-01-2020 17:09
# 18                19  02-01-2020 20:00   01-01-2020 18:00   02-01-2020 10:42
# 60                61  03-01-2020 22:00   01-03-2020 12:00   03-01-2020 15:04
# 81                82  06-01-2020 05:00   01-04-2020 09:00   04-01-2020 15:37
# ...              ...               ...                ...                ...
# 40124          40125  01-08-2024 11:00   07-29-2024 20:00   30-07-2024 11:02
# ...

# %%
#crime domain
df['Crime Domain'].value_counts()
# Out:
# Crime Domain
# Other Crime         22948
# Violent Crime       11472
# Fire Accident        3825
# Traffic Fatality     1915
# Name: count, dtype: int64

# %%
#victim gender
df['Victim Gender'].value_counts()
# Out:
# Victim Gender
# F    22423
# M    13405
# X     4332
# Name: count, dtype: int64

# %%
#weapons used
df['Weapon Used'].value_counts()
# Out:
# Weapon Used
# Knife           5835
# Explosives      5751
# Blunt Object    5737
# Poison          5728
# Other           5676
# Firearm         5643
# Name: count, dtype: int64

# %%
#case status
#this will directly answer how many cases are open and closed
df['Case Closed'].value_counts()
# Out:
# Case Closed
# No     20098
# Yes    20062
# Name: count, dtype: int64

# %%
#highest victim age
df.sort_values('Victim Age', ascending=False).head(10)
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 38045          38046  05-05-2024 19:00   05-04-2024 05:00   04-05-2024 18:33
# 26807          26808  22-01-2023 02:00   01-21-2023 23:00   22-01-2023 17:54
# 38041          38042  05-05-2024 17:00   05-04-2024 01:00   04-05-2024 23:06
# 35130          35131  06-01-2024 16:00   01-03-2024 18:00   04-01-2024 17:32
# 35135          35136  06-01-2024 18:00   01-03-2024 23:00   04-01-2024 08:54
# 18737          18738  20-02-2022 16:00   02-19-2022 17:00   19-02-2022 23:28
# 1274            1275  25-02-2020 10:00   02-23-2020 02:00   23-02-2020 16:22
# 13843          13844  01-08-2021 21:00   07-30-2021 19:00   31-07-2021 09:25
# 13856          13857  01-08-2021 07:00   07-31-2021 08:00   01-08-2021 01:22
# 18795          18796  23-02-2022 20:00   02-22-2022 03:00   22-02-2022 21:41
#
#                 City  Crime Code  Crime Description  Victim Age Victim Gender  \
# ...

# %%
#lowest victim age
df.sort_values('Victim Age').head(10)
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 24055          24056  01-10-2022 08:00   09-29-2022 07:00   29-09-2022 17:30
# 21711          21712  24-06-2022 06:00   06-23-2022 15:00   24-06-2022 05:06
# 35092          35093  02-01-2024 08:00   01-02-2024 04:00   02-01-2024 15:32
# 18961          18962  03-03-2022 23:00   03-01-2022 01:00   01-03-2022 07:49
# 14431          14432  27-08-2021 05:00   08-24-2021 07:00   24-08-2021 09:48
# 22495          22496  28-07-2022 10:00   07-26-2022 07:00   26-07-2022 15:15
# 9012            9013  12-01-2021 07:00   01-10-2021 12:00   10-01-2021 17:24
# 660              661  29-01-2020 12:00   01-28-2020 12:00   29-01-2020 10:40
# 5711            5712  27-08-2020 02:00   08-25-2020 23:00   26-08-2020 18:01
# 33623          33624  04-11-2023 09:00   11-01-2023 23:00   02-11-2023 14:09
#
#                 City  Crime Code   Crime Description  Victim Age  \
# ...

# %%
#most police deployed
df.sort_values('Police Deployed', ascending=False).head(10)
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 16918          16919  06-12-2021 06:00   12-05-2021 22:00   06-12-2021 00:26
# 16920          16921  07-12-2021 01:00   12-06-2021 00:00   06-12-2021 22:24
# 32                33  03-01-2020 04:00   01-02-2020 08:00   03-01-2020 03:01
# 8387            8388  17-12-2020 14:00   12-15-2020 11:00   15-12-2020 12:01
# 40113          40114  01-08-2024 08:00   07-29-2024 09:00   30-07-2024 08:55
# 4205            4206  27-06-2020 02:00   06-24-2020 05:00   24-06-2020 12:54
# 34294          34295  01-12-2023 18:00   11-29-2023 22:00   30-11-2023 21:43
# 4210            4211  26-06-2020 10:00   06-24-2020 10:00   25-06-2020 04:48
# 4215            4216  24-06-2020 22:00   06-24-2020 15:00   25-06-2020 11:49
# 34305          34306  30-11-2023 11:00   11-30-2023 09:00   01-12-2023 08:12
#
#             City  Crime Code   Crime Description  Victim Age Victim Gender  \
# ...

# %%
df['Victim Gender'].value_counts()
# Out:
# Victim Gender
# F    22423
# M    13405
# X     4332
# Name: count, dtype: int64

# %%
#no. of female victims
df[df['Victim Gender'] == 'F']
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# 6                  7  01-01-2020 16:00   01-01-2020 06:00   01-01-2020 14:08
# 12                13  01-01-2020 16:00   01-01-2020 12:00   01-01-2020 23:14
# ...              ...               ...                ...                ...
# 40153          40154  31-07-2024 17:00   07-31-2024 01:00   31-07-2024 21:42
# 40154          40155  01-08-2024 11:00   07-31-2024 02:00   31-07-2024 12:59
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
#no. of male victims
df[df['Victim Gender'] == 'M']
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 5                  6  02-01-2020 03:00   01-01-2020 05:00   01-01-2020 17:09
# 9                 10  03-01-2020 07:00   01-01-2020 09:00   01-01-2020 17:50
# 10                11  02-01-2020 13:00   01-01-2020 10:00   01-01-2020 19:42
# ...              ...               ...                ...                ...
# 40145          40146  31-07-2024 22:00   07-30-2024 17:00   31-07-2024 00:01
# ...

# %%
df[ (df['Victim Gender'] == 'F') & (df['Victim Age'] > 30)]
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 6                  7  01-01-2020 16:00   01-01-2020 06:00   01-01-2020 14:08
# 12                13  01-01-2020 16:00   01-01-2020 12:00   01-01-2020 23:14
# 14                15  02-01-2020 00:00   01-01-2020 14:00   01-01-2020 22:28
# ...              ...               ...                ...                ...
# 40153          40154  31-07-2024 17:00   07-31-2024 01:00   31-07-2024 21:42
# 40154          40155  01-08-2024 11:00   07-31-2024 02:00   31-07-2024 12:59
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
#adult victims and their cases are still open
df[ (df['Victim Age'] > 18) & (df['Case Closed'] == 'No') ]
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 7                  8  02-01-2020 10:00   01-01-2020 07:00   02-01-2020 06:33
# 8                  9  04-01-2020 03:00   01-01-2020 08:00   02-01-2020 06:34
# 9                 10  03-01-2020 07:00   01-01-2020 09:00   01-01-2020 17:50
# ...              ...               ...                ...                ...
# 40150          40151  01-08-2024 23:00   07-30-2024 22:00   31-07-2024 19:41
# 40152          40153  02-08-2024 11:00   07-31-2024 00:00   31-07-2024 03:46
# 40154          40155  01-08-2024 11:00   07-31-2024 02:00   31-07-2024 12:59
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
#
# ...

# %%
#Access rows by index
df.iloc[0:5]
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0              1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1              2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2              3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3              4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4              5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
#
#         City  Crime Code Crime Description  Victim Age Victim Gender  \
# 0  Ahmedabad         576    IDENTITY THEFT          16             M
# 1    Chennai         128          HOMICIDE          37             M
# ...

# %%
#crimes per city
df.groupby('City').size().sort_values(ascending=False)
# Out:
# City
# Delhi            5400
# Mumbai           4415
# Bangalore        3588
# Hyderabad        2881
# Kolkata          2518
# Chennai          2493
# Pune             2212
# Ahmedabad        1817
# Jaipur           1479
# Lucknow          1456
# Kanpur           1112
# Surat            1111
# Nagpur           1053
# Agra              764
# Ludhiana          761
# Visakhapatnam     728
# Thane             706
# Ghaziabad         704
# Indore            699
# Patna             695
# Bhopal            690
# Meerut            395
# Srinagar          371
# Nashik            366
# Vasai             362
# Varanasi          355
# Kalyan            355
# Faridabad         354
# Rajkot            320
# dtype: int64

# %%
#average victim age by crime
df.groupby('Crime Description')['Victim Age'].mean().sort_values(ascending=False )
# Out:
# Crime Description
# EXTORTION              45.698345
# VANDALISM              45.597975
# ILLEGAL POSSESSION     45.361478
# IDENTITY THEFT         45.039625
# SHOPLIFTING            44.947283
# COUNTERFEITING         44.801176
# VEHICLE - STOLEN       44.656821
# DOMESTIC VIOLENCE      44.589545
# ARSON                  44.407075
# ROBBERY                44.405083
# HOMICIDE               44.374542
# PUBLIC INTOXICATION    44.265167
# FRAUD                  44.246310
# SEXUAL ASSAULT         44.199791
# FIREARM OFFENSE        44.130502
# DRUG OFFENSE           44.102646
# BURGLARY               44.069192
# KIDNAPPING             44.029688
# CYBERCRIME             44.013165
# TRAFFIC VIOLATION      43.865274
# ASSAULT                43.555091
# Name: Victim Age, dtype: float64

# %%
#Statistics
#Mean Of a column
df['Victim Age'].mean()
# Out:
# np.float64(44.49125996015936)

# %%
# Histogram

import matplotlib.pyplot as plt
import seaborn as sns

plt.hist(df['Victim Age'])
plt.xlabel('Victim Age')
plt.ylabel('Frequency')
plt.title('Victim Age Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

gender = df['Victim Gender'].value_counts()

plt.pie(gender.values, labels=gender.index, autopct='%1.1f%%')
plt.title('Crime Distribution by Victim Gender')
plt.show()
